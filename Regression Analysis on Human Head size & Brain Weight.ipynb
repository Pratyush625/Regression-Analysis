# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('headbrain.csv')
df
# Out:
#      Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0         1          1             4512                 1530
# 1         1          1             3738                 1297
# 2         1          1             4261                 1335
# 3         1          1             3777                 1282
# 4         1          1             4177                 1590
# 5         1          1             3585                 1300
# 6         1          1             3785                 1400
# 7         1          1             3559                 1255
# 8         1          1             3613                 1355
# 9         1          1             3982                 1375
# 10        1          1             3443                 1340
# 11        1          1             3993                 1380
# 12        1          1             3640                 1355
# 13        1          1             4208                 1522
# ...

# %%
x=df.iloc[:,:-1]
x
# Out:
#      Gender  Age Range  Head Size(cm^3)
# 0         1          1             4512
# 1         1          1             3738
# 2         1          1             4261
# 3         1          1             3777
# 4         1          1             4177
# 5         1          1             3585
# 6         1          1             3785
# 7         1          1             3559
# 8         1          1             3613
# 9         1          1             3982
# 10        1          1             3443
# 11        1          1             3993
# 12        1          1             3640
# 13        1          1             4208
# 14        1          1             3832
# 15        1          1             3876
# 16        1          1             3497
# 17        1          1             3466
# 18        1          1             3095
# 19        1          1             4424
# 20        1          1             3878
# 21        1          1             4046
# ...

# %%
y=df['Brain Weight(grams)']
y
# Out:
# 0      1530
# 1      1297
# 2      1335
# 3      1282
# 4      1590
# 5      1300
# 6      1400
# 7      1255
# 8      1355
# 9      1375
# 10     1340
# 11     1380
# 12     1355
# 13     1522
# 14     1208
# 15     1405
# 16     1358
# 17     1292
# 18     1340
# 19     1400
# 20     1357
# 21     1287
# 22     1275
# 23     1270
# 24     1635
# 25     1505
# 26     1490
# 27     1485
# 28     1310
# 29     1420
#        ...
# 207    1296
# 208    1175
# 209     955
# 210    1070
# 211    1320
# 212    1060
# 213    1130
# 214    1250
# 215    1225
# 216    1180
# 217    1178
# 218    1142
# 219    1130
# 220    1185
# 221    1012
# 222    1280
# 223    1103
# 224    1408
# 225    1300
# 226    1246
# 227    1380
# 228    1350
# 229    1060
# 230    1350
# 231    1220
# 232    1110
# 233    1215
# 234    1104
# 235    1170
# 236    1120
# Name: Brain Weight(grams), Length: 237, dtype: int64

# %%
import matplotlib.pyplot as pt
# %matplotlib inline

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=4)

# %%
linreg=LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
prediction=linreg.predict(x_test)
prediction
# Out:
# array([1429.27430898, 1240.01308878, 1256.26693999, 1461.78201141,
#        1239.2511895 , 1393.97297587, 1257.5930055 , 1206.95741903,
#        1384.10831974, 1179.78301153, 1196.33086363, 1175.71954873,
#        1291.5682731 , 1232.86199441, 1474.22636625, 1260.6406026 ,
#        1256.87114068, 1438.71110117, 1219.44180833, 1343.21972527,
#        1239.56138931, 1188.41786999, 1239.75912235, 1107.65654675,
#        1196.83879648, 1280.19601735, 1202.99022407, 1426.77467918,
#        1336.10866536, 1287.56104368, 1319.3468813 , 1156.04646985,
#        1173.82411962, 1244.13278496, 1348.00505289, 1207.71931831,
#        1405.65543143, 1150.83083905, 1394.52094318, 1341.40192584,
#        1036.54594768, 1333.52896665, 1328.957571  , 1232.4503294 ,
#        1328.44963815, 1171.95008681, 1339.37019443, 1170.13228737,
#        1301.21899726, 1426.01277991, 1295.59170145, 1174.29201801,
#        1373.14772899, 1367.05253479, 1204.41775478, 1178.00524655,
# ...

# %%
y_test
# Out:
# 63     1485
# 153    1192
# 171    1240
# 69     1415
# 135    1235
# 118    1362
# 83     1245
# 236    1120
# 11     1380
# 226    1246
# 147    1243
# 218    1142
# 185    1205
# 198    1240
# 68     1510
# 116    1250
# 39     1250
# 13     1522
# 167    1190
# 14     1208
# 88     1280
# 208    1175
# 143    1290
# 192    1090
# 159    1241
# 130    1270
# 77     1188
# 33     1405
# 43     1570
# 110    1310
#        ...
# 71     1390
# 99     1270
# 81     1430
# 139    1127
# 93     1346
# 216    1180
# 152    1321
# 34     1432
# 222    1280
# 82     1279
# 106    1425
# 70     1468
# 220    1185
# 202    1105
# 48     1311
# 142    1200
# 6      1400
# 123    1180
# 26     1490
# 191    1204
# 182    1280
# 91     1192
# 12     1355
# 101    1430
# 146    1140
# 133    1310
# 134    1027
# 124    1306
# 62     1330
# 223    1103
# Name: Brain Weight(grams), Length: 72, dtype: int64

# %%
Mean_square_error=mean_squared_error(y_test,prediction)
Mean_square_error
# Out:
# 5513.227509880805

# %%
import numpy as np

# %%
RMS_error=np.sqrt(Mean_square_error)
RMS_error
# Out:
# 74.25111116933405

# %%
import seaborn as sns

# %%
sns.pairplot(df,x_vars=['Head Size(cm^3)'],y_vars=['Brain Weight(grams)'],size=7,aspect=0.7)

# %%
sns.pairplot(df,x_vars=['Head Size(cm^3)'],y_vars=['Brain Weight(grams)'],size=7,aspect=0.7,kind='reg')

# %%
r2_score(y_test,prediction)
# Out:
# 0.6491812066420074

# %% [markdown]
# # End
